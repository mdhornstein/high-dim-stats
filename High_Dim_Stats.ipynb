# %% [markdown]
# <a href="https://colab.research.google.com/github/mdhornstein/high-dim-stats/blob/main/High_Dim_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 

from numpy.random import default_rng

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
rng = default_rng() 
ns = [int(10 ** i) for i in range(1, 5)]
vals = [rng.standard_normal(n) for n in ns]

fig, axes = plt.subplots(1, len(ns), figsize=(6 * len(ns), 4))
for i, n in enumerate(ns):
  sns.histplot(vals[i], ax=axes[i])
  axes[i].set_title('n = {}'.format(n), fontsize=15)
